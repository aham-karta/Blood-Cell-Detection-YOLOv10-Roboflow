# %%
from inference_sdk import InferenceHTTPClient

CLIENT = InferenceHTTPClient(
    api_url="https://detect.roboflow.com",
    api_key=""
)

result = CLIENT.infer("PLATELET.jpg", model_id="blood-bmtoe/1")

# %%
result
# Out:
# {'inference_id': 'e8419e39-73c3-41c3-bd8b-9eb2380a45f1',
#  'time': 0.04786232399999335,
#  'image': {'width': 360, 'height': 363},
#  'predictions': [{'x': 180.0,
#    'y': 187.0,
#    'width': 72.0,
#    'height': 72.0,
#    'confidence': 0.8385344743728638,
#    'class': 'platelet',
#    'class_id': 7,
#    'detection_id': 'e8884f9c-80b9-494e-a3ff-4a9b6218e7f3'}]}

# %%
# %pip install pillow matplotlib
# Out:
# Requirement already satisfied: pillow in c:\users\srisi\onedrive\desktop\sidxt\hub\blood2\.venv\lib\site-packages (10.4.0)
# Requirement already satisfied: matplotlib in c:\users\srisi\onedrive\desktop\sidxt\hub\blood2\.venv\lib\site-packages (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\srisi\onedrive\desktop\sidxt\hub\blood2\.venv\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\srisi\onedrive\desktop\sidxt\hub\blood2\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\srisi\onedrive\desktop\sidxt\hub\blood2\.venv\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\srisi\onedrive\desktop\sidxt\hub\blood2\.venv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\srisi\onedrive\desktop\sidxt\hub\blood2\.venv\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\srisi\onedrive\desktop\sidxt\hub\blood2\.venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\srisi\onedrive\desktop\sidxt\hub\blood2\.venv\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\srisi\onedrive\desktop\sidxt\hub\blood2\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\srisi\onedrive\desktop\sidxt\hub\blood2\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
image_path = "PLATELET.jpg"
image = Image.open(image_path)
draw = ImageDraw.Draw(image)
for prediction in result['predictions']:
    x = prediction['x']
    y = prediction['y']
    width = prediction['width']
    height = prediction['height']
    left = x - width / 2
    top = y - height / 2
    right = x + width / 2
    bottom = y + height / 2
    draw.rectangle([left, top, right, bottom], outline="red", width=2)
    draw.text((left, top), prediction['class'], fill="red")
plt.imshow(image)
plt.axis("off")
plt.show()
